# %% [markdown]
# The above data is data for Prebid auctions. There are bidders who receive requests for placing ads, they respond to these requests with a bid and the highest bid wins the auction. Analyse the dataset to answer which bidder has the highest win rate (wins / total_bid).
#
#
# 	date_hour	client	device_type	time_zone	os_name	browser_name	ad_unit	size	bidder	bid_range	media_type	request_count	response_count	prebid_win_count	win_count	sum_bid	sum_time_to_respond	median	min_bid	max_bid	avg_bid	sum_2nd_highest_bid	sum_prebid_winning_bid	sum_winning_bid	sum_nobid	sum_timeout

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('analysis_id(in).csv')
df.head()
# Out:
#    Unnamed: 0            date_hour     client device_type        time_zone  \
# 0           0  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 1           1  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 2           2  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 3           3  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
# 4           4  2021-04-11T01:00:00  asc126828     Desktop  America/Chicago
#
#   os_name        browser_name                      ad_unit     size  \
# 0   Linux  Chrome-85.04183133      div-gpt-ad-BT-D-Footers   728x90
# 1   Linux  Chrome-85.04183133      div-gpt-ad-BT-D-Footers   728x90
# 2   Linux  Chrome-85.04183133     div-gpt-ad-BT-D-InLine-1  300x250
# 3   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-O-300x250-1  300x250
# 4   Linux  Chrome-85.04183133  div-gpt-ad-BT-D-O-300x250-1  300x250
#
#       bidder  ... sum_time_to_respond   median  min_bid  max_bid   avg_bid  \
# ...

# %%
df['win_rate']=df['prebid_win_count']/df['response_count']

# %%
df_sorted=df.sort_values(by='win_rate',ascending=False)

# %%
df_sorted[['bidder','response_count','prebid_win_count','win_rate']].head()
# Out:
#           bidder  response_count  prebid_win_count  win_rate
# 4988    medianet               1               1.0       1.0
# 3641    medianet               3               3.0       1.0
# 1936  pulsepoint               1               1.0       1.0
# 3786   undertone               1               1.0       1.0
# 3779     rubicon               1               1.0       1.0

# %%
df_sorted.groupby('bidder').sum()['win_rate']
# Out:
# bidder
#                   0.000000
# 33across         51.811502
# appnexus         52.019670
# criteo           57.113528
# emx_digital      26.100394
# ix               63.282496
# medianet         72.007631
# onemobile       129.578778
# openx            24.938312
# pubmatic         47.810970
# pulsepoint       53.816667
# rhythmone        61.688845
# rubicon          18.778268
# sharethrough     49.998910
# sovrn             6.666667
# teads            19.205561
# triplelift       33.602842
# undertone        23.763919
# Name: win_rate, dtype: float64

# %% [markdown]
# Describe how you would build a logistic regression model to predict the probability of a bid winning (win) based on the other columns. What features would you select and why?
#
#
#
# I would frame this as a binary classification problem, where the target is whether a bid wins or not.
#
# I'll use features such as 'bid_range', 'request_count', 'response_count', 'prebid_win-count', 'win_count' &
# 'sum_bid' as our features for the model bacause these features directly influence the outcome of the auction.
#
# This will make the model effective and explainable.
